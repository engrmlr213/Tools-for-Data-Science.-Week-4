# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Mark Lester C. Real**
#
# **Current Occupation: Engineer**
#
# **Desired Occupation: Data Scientist**

# %% [markdown]
# *I am interested in data science because I want to work efficiently and be able to analyze big data faster, and in a more professional manner.*

# %% [markdown]
# ### The next cell is an example problem on using the math module that is part of the Python Standard Library.

# %%
from math import cos

x = 2
y = cos(x)

print(y)
# Out:
# -0.4161468365471424

# %% [markdown]
# ### Horizontal rule
#
# This content is above the horizontal rule.
# ***
# This content is below the horizontal rule.

# %% [markdown]
# ### Blockquotes

# %% [markdown]
# > "*Whoever controls data will have control over the world in the future.*"
# >
# > -Prime Minister Narendra Modi

# %% [markdown]
# ### Image
#
# The Order of DeMolay is a character-building and leadership development organization for young men between the ages of 13 and 21. The ultimate aim of the organization is to build better sons which will, in turn, mean better men to be better citizens, husbands, fathers, friends and leaders in the future.
#
# ![Demolaicon.png](attachment:Demolaicon.png)

# %% [markdown]
# ### Numbered list
#
# A sample list of the expected contents of your Table of Contents:
#
# 1. Introduction
# 2. The History of Grammar
# 3. Parts of Speech
#
#     3.1 Nouns
#     3.2 Verbs
#     3.3 Adjectives
#     3.4 Adverbs
#
# 4. Sentences
#
#     4.1 Complex Sentences
#     4.2 Compound Sentences
#
# 5. Paragraphs
#
#     5.1 Descriptive
#     5.2 Expository
#     5.3 Narrative
#     5.4 Persuasive
#
# 6. Conclusion
# 7. Appendix
# 8. Resources
#
# ### Hyperlinks
#
# Adapted from (https://assets.ltkcontent.com/files/table-contents-2.pdf)
